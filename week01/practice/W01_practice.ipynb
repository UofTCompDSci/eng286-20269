# %% [markdown]
# # Practice Notebook 1
#
#
# ## Instructions
#
# This notebook will not be graded.  It is intended to help you get started learning to program. This notebook is mostly about getting Jupyter notebooks working and learning to upload assignments to Markus and run some basic tests.
#
# There is also another example of the kind of mad lib poetry generation that we talked about in class.
#
# While this notebook will not be graded, you can still submit it to MarkUs to see if it passes the tests.
#
# We recommend completing this notebook before you come to lecture in Week 2.

# %% [markdown]
# ## Task 1: Writing in a Markdown cell
#
# In the cell below this explanation, edit the text to introduce yourself a little. Replace the stuff in `[SQUARE BRACKETS]` with the information about yourself (removing those ugly square brackets in the process). Then "run" the cell.

# %% [markdown]
# [GREETING]! My name is **[NAME]**. I'm a [YEARth] year student studying [YOUR PROGRAM(S)]. If I could pick only one favourite book, it would be *[TITLE]*.

# %% [markdown]
# ## Task 2: Write a Markdown list
#
# Use the Markdown list notation to write an unnumbered list of your next three favourite books. You can find out how to write a Markdown list by reading the [Cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet), or by checking how similar cells look in the lecture notebok.

# %% [markdown]
# Write your list here

# %% [markdown]
# ### Task 3: Setting up variables
#
# Below is an example of a mad lib style poetry generator similar to one introduced in class. In this exercise, you need to type (or copy and paste) the variables into the code cell below.  Here are the names and descriptions of the variables you need to create:
#
# |variable name | number of syllables | description|
# |--------------|---------------------|------------|
# |cosmic_noun  | 3 syllable  | something in space|
# |kitchen_verb | 1 syllable  | a cooking action |
# |liquid_noun  | 2 syllables | a fluid|
# |colour        | 2 syllables | a colour |
# |texture_adj  | 1 syllable  | a tactile description |
# |object_plural| 1 syllable  | items you can touch |
# |small_verb   | 1 syllable  | a physical movement|
#
# In the first student you will create 7 variables and give them values. The variable `colour` is defined below as an example, but you are welcome to give it a different value. Remember to put the words in quotation marks, otherwise Python will treat it as a variable name.
#
# Then run the cell to see the poem.

# %%
# --- STEP 1: Create the variabes as defined in the table above and 
# give them values. Remember to put the words in quotes.

colour = "crimson"



# --- STEP 2: Create the lines of poetry using the variables.

line1 = cosmic_noun + " " + kitchen_verb + " " + liquid_noun + ","
line2 = colour + " " + texture_adj + " " + object_plural + " " + small_verb + " down,"
line3 = "Into the " + liquid_noun + "."

print(line1)
print(line2)
print(line3)

# %% [markdown]
# ## How to Submit
#
# 1. Do the assignment by editing this notebook, writing in the designated cells.
#
# 2. Download the completed notebook. Save it as `W01_practice.ipynb`.
#     - on Jupyterlab you will use the menu item `File -> Download`
#     - on Jupyterhub use the menu item `File —> Download As —> Notebook (.ipynb)`.
#
# 3. Log in here with your UTORid: https://markus.teach.cs.toronto.edu/markus/ (Tip: Control/Command-click to open it in a new tab so you can still see these instructions.)
#
# 4. Choose your course (ENG286).
#
# 5. Click the `prac01: Practice` assessment.
#
# 6. Click the `Submissions` tab. The new page is `Practice: Submissions`.
#
# 7. Click button `Submit File` on the right.
#
# 8. In the popup window that opens, click button `Browse`/`Choose Files` and select the `W01_practice.ipynb` file that you downloaded.
#
# 9. MarkUs is picky with filenames! If your notebook file has a different name (e.g., `W01_practice (1).ipynb`), use the dropdown menu to rename it when you submit the file.
#
# 10. You can upload your work as many times as you want before the deadline. (There is no deadline for practice labs.)
#
# 11. Run the tests.

# %% [markdown]
# ## How to Run the Autotester
#
# *After* submitting your work, you can run the autotester in MarkUs by doing the following:
#
# 1. On MarkUs, go to ENG286 course and the assignment page (e.g., `prac01: Practice`).
# 2. Click on the "Automated Testing" tab, which is beside "Submissions".
# 3. On the new page, click on the "Run tests" button to run the autograder for this homework.
# 4. Please wait a few minutes (since it takes a bit of time for the tests to run, and the autograder is serving many students and courses at the same time!), and then refresh the page.
# 5. You'll see a table of test results, where each row represents one test.
#
#     - Green rows indicate that the test passed, so your code was correct (based on whatever the test was checking).
#     - Red rows indicate that the test failed, so there was a problem with your code.
#         If this happens, please read the test message carefully, and make sure to click on the triangle on the left side of the test row to see additional information.
#
# If all of the rows are green, that's great! The basic tests work on your code.  For the practice and tutorial notebooks (where applicable), we will give you all of the tests.  For the labs, we will give you some basic tests but we will also run additional tests that will form the mark for those labs.
#
# If some of the rows are red, you can then make changes to your notebook on JupyterHub, and then re-submit and re-run the tests.
#
# You can do this as many times as you like up until the lab deadline.
