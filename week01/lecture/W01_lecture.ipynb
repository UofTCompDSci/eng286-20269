# %% [markdown]
# # Week 1: Getting the lay of the land
#
# ### Tools
# - JupyterHub (or JupyterLab)
# - MarkUs
# - Piazza
# - Quercus
#
# ### Text book reference
#
# Melanie Walsh', [Introduction to Cultural Analytics & Python](https://melaniewalsh.github.io/Intro-Cultural-Analytics/welcome.html). It's not suuuuper helpful this week, since JupyterHub is a U of T thing and Walsh expects her readers to be accessing notebooks in a slightly different way. But you might still want to have a look at [the introductory page to the material on Python](https://melaniewalsh.github.io/Intro-Cultural-Analytics/02-Python/00-Python.html)
#
# We will be referring to Adam Pritchard's [Markdown Cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)

# %% [markdown]
# ## 1. What is Jupyter Lab?

# %% [markdown]
# The **University of Toronto Jupyter Lab** is a website that hosts and runs Jupyter notebooks.
#
# Top five things to know:
#
# 1. URL: <https://jupyter.utoronto.ca>. To login you'll need your University email, and then UTORid and password.
# 2. Since files are stored and run "in the cloud", you can **access your work from any computer with an Internet connection**, and **without installing any software**!
# 3. Every week, we'll post links on the course syllabus that **automatically open notebook files on Jupyter Lab** to complete your work on Jupyter Lab.
# 4. But, you'll still need to **download each notebook to submit to MarkUs**.
# 5. You have to click the link on Quercus to get the updates each week.
#
# The university actually supports two different environments: JupyterHub and JupyterLab. JupyterHub is the older and perhaps simpler version. JupyterLab has more features including a debugger which can be very handy when code gets a little more complicated.  I'm recommending that you use Jupyter Lab even though it includes a bunch of features that you are unlikely to use.

# %% [markdown]
# ## 2. What is a Jupyter Notebook?
#
# Think of it like a Microsoft Word file or a Google Doc that can do some things that neither of those can.
# * you can write text and format it with things like *italics*, **bolding**, etc.
# * you can also **DO PROGRAMMING** in a Jupyter Notebook. Which is why we're using them!
#
# The basic unit of a Jupyter Notebook is a *cell* (not to be confused with a jail cell).
#
# You can create a new cell by clicking the plus `+` sign in the toolbar or by pressing `Option` + `Return` (Mac) / `Alt` `Return` (Windows).
#
# We will use two different types of cells: **Markdown cells** and **Code cells**. You can switch between types by accessing the "Cell" --> "Cell Type" menu

# %% [markdown]
# ### Markdown and Markdown Cells
#
# Markdown is a "language" that allows you to format text.
#
# When you first view this cell you see the results of the formatting. To see and edit the Markdown text itself, double-click on the cell. To go back to "display mode" you can click the run button when this cell is selected.
#
# Here are some commonly used formatting options:
#
# `Make text *italicized*`: Make text *italized*
#
# `Make text **bold**`: Make text **bold**
#
# `Make text a link to [a website](https://piazza.com/class/mtiqkqw9t4k51h/)`: Make text a link to [a website](https://piazza.com/class/mtiqkqw9t4k51h)
#
# ``Make text `code` ``: Make text `code`
#
# (The kind of tricky one here is that surrounding text in backquotes (`) makes the text look like formatted code, but also shows exactly the characters that were typed.)
#
# See lots more fun Markdown stuff at Adam Pritchard's [Markdown Cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)

# %% [markdown]
# ### "Running" Cells
#
# Cells in Jupyter notebooks have two "states": the "editing" state and the "output" state.
#
# To "run" a Markdown cell, you can either click the play button ▶️ on the toolbar above or by typing `Shift` + `Return` on Windows or  `Command` + `Return` on a Mac.
#
# Once a Markdown cell has been "run," if you want to return to the "coding" state to edit your Markdown code, you can just double click on the cell in question.

# %% [markdown]
# ## 2. What is a Code Cell? What is Python?
#
# Python is another "language": a general-purpose programming language.
#
# Code cells in a Jupyter Notebook expect Python code.
#
# Let's start with the basics of Python: the "hello," "goodbye," "one beer, please," of the language...
#
# For instance, the below is perfectly valid code. The Python interpreter will understand it, consider it, and give you an answer:

# %%
2 + 3

# %% [markdown]
# Note that it will also understand this rather simpler command

# %%
2

# %% [markdown]
# Now, as English students, you're probably all more interested in *words* than *numbers*, right? Well, thankfully, Python is also capable of understanding and doing things with words. On the condition, that is, that we put these words `"into quotation marks"`, so that Python understands they're words, not some other kind of code.

# %%
two

# %%
"two"

# %% [markdown]
# Amusingly, due to something called "polymorphism," many of the mathematical operations we've just met also produce results when applied to `"words"` — though what they do to words is different from what they do to numbers... more like metaphorical addition than actual addition.
#
# Let's work throught the following examples and try to figure out what they tell us about Python, how it thinks, and how it deal with numbers and words...

# %%
"two" + "three"

# %%
"two" - "three"

# %% [markdown]
# Now, why does the first one not work, but the second one does?

# %%
"two" * "three"

# %%
"two" * 3

# %%
"My name is Karen" * 3

# %% [markdown]
# ### 3. Python Variables
#
# Everything we have put into a code cell so far is called an _expression_.
#
# Most of the time we want to save the result of the expression to use later, so we _assign_ the result of the expression to a _variable_.
#
# Variables have two main aspects: "names" and "values." The name tells Python where to look for the contents of the container. The "value" of the variable is that content.
#
# To put the contents into the container (as it were), you need to *assign* a *value* to the *variable*.
#
# Below, I'll put a name into a variable called... `name`!

# %%
name = "Karen"  # assign the value "Karen" to the variable name
name  # use the variable as an expression so jupyter will print it

# %% [markdown]
# ### 4. Exercise 1
#
# Now let's have some fun. I'm sure you have played with various online quizzes that will generate a name based on some factor. In this small example, we are going to create city or town names by picking a stem name from a list and then picking a suffix from another list.
#
# The code is shown below. This also gives me a chance to show you some more python.  We will talk about the details in the coming weeks, but I'm including comments in the code below to explain each line, fully recognizing that I'm throwing some new terms at you like "list", "function", and "module".
#
# Try running the code cell below a few times to see the results.

# %%
# random is a module that contains functions for generating random numbers
import random

# stem_list is a variable.  We are assigning a list of strings to it
stem_list = ['Spring', 'Hill', 'Sunny', 'Storm', 'Wind', 'Meadow', 'Ever', 'Shroud', 'Crag', 'Rock']

suffix_list = ['ville', 'town', 'run', 'burg', 'ton', 'field', 'mount', 'dell', 'wood', 'dale']

# random.choice() is a function that returns a random element from a list
stem = random.choice(stem_list)
suffix = random.choice(suffix_list)

# disply the "sum" of the stem and suffix
stem + suffix

# %% [markdown]
# ### 5. The Concept of a Function
#
# So far we've been checking the contents of our variables by just typing their names into a code cell.
#
# Another way of doing this is to use a **function** called `print()`.
#
# Analogy: `verb(noun)` — no spaces by convention.
#
# The Python terminology for these things is `function(argument)`.

# %%
print("Hello world")

# %% [markdown]
# We can also provide a variable in the "noun" or *argument* position
#
# As always, the syntax is `verb(noun)` — getting any part of that syntax wrong will cause the Python interpreter will return an error message:
# * name of the function misspelt, even slightly
# * name of variable misspelt, even slightly
# * space between function name and variable name
# * missing parenthesis, or parenthesis pointing in wrong direction
# * curly or square bracket used rather than parentheses.
#
# Think of the Python interpreter as an extraordinarily dutiful but uncompromisingly literal reader.
#
# Run each of the cell below to see what the error message is. You should expect to read and decipher **lots** of error messages when you are programming. It may not look like it, but the Python interpreter is trying to help you figure out the error.

# %%
prnit(name)

# %%
print(nam3)

# %%
print name

# %%
print("Hello"

# %%
print["Hello"]

# %% [markdown]
# ### 5. Now it's your turn
#
# In our first few weeks of programming we are going to work towards writing Python code to generate poetry. Let's start simple with a mad lib style poetry.
#
# Your task is to give values to the variables below.  Try to do this without looking at the Step 2. Then run the cell to see your poem!

# %%
# --- STEP 1: FILL IN BLINDLY ---
# Do not read Step 2 yet! Just provide words between the quotation marks 
# that match the description from the comment above each variable.

# Set noun_1 to a a word that has 3 syllables and is a person or thing
noun_1    = ""   

# Set place_1 to a a word that has 2 syllables and is a location
place_1   = ""    

# Set verb_ing to a a word that has 2 syllables and ends in -ing
verb_ing  = ""   

# Set adj_1 to a a word that has 2 syllables and is a descriptive word
adj_1     = ""    

# Set noun_2 to a a word that has 2 syllables and is a concrete object
noun_2    = ""   

# Set emotion to a a word that has 2 syllables and is a feeling or abstract noun
emotion   = ""

# %%
# --- STEP 2: THE REVEAL ENGINE ---
# Syntax: Line 1 (3+2=5) | Line 2 (2+2+3=7) | Line 3 (1+2+2=5)

line1 = "The " + noun_1 + " waits,"
line2 = "Inside a " + place_1 + " " + verb_ing + ","
line3 = "With " + adj_1 + " " + emotion + "."

print(line1)
print(line2)
print(line3)

# %% [markdown]
# ### 6. Challenge
#
# Using the code in part 5 see if you can modify the lines to create a different kind of poem. You can start simple by changing the words in `line1`, `line2`, and `line3`. Then try creating a different sentence structure in each line and use different types of words.

# %%
# Write your code here
